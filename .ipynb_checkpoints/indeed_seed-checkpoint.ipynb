# %%
import pandas as pd

# %%
df = pd.read_csv('indeed_seed.csv')

# %%
df.head(50)
# Out:
#             search_terms     search_loc  \
# 0   javascript developer  Charlotte, NC
# 1   javascript developer  Charlotte, NC
# 2   javascript developer  Charlotte, NC
# 3   javascript developer  Charlotte, NC
# 4   javascript developer  Charlotte, NC
# 5   javascript developer  Charlotte, NC
# 6   javascript developer  Charlotte, NC
# 7   javascript developer  Charlotte, NC
# 8   javascript developer  Charlotte, NC
# 9   javascript developer  Charlotte, NC
# 10  javascript developer  Charlotte, NC
# 11  javascript developer  Charlotte, NC
# 12  javascript developer  Charlotte, NC
# 13  javascript developer  Charlotte, NC
# 14  javascript developer  Charlotte, NC
# 15  javascript developer  Charlotte, NC
# 16  javascript developer  Charlotte, NC
# 17  javascript developer  Charlotte, NC
# 18  javascript developer  Charlotte, NC
# 19  javascript developer  Charlotte, NC
# 20  javascript developer  Charlotte, NC
# 21  javascript developer  Charlotte, NC
# ...
